# %%
import pandas as pd
# Out:
# /var/folders/3w/wl135nsj51x6pw5s6wdgpq1h0000gn/T/ipykernel_26842/2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("/Users/bytedance/PycharmProjects/Finance_Project/used_etf/513050-中概互联网ETF.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          日期     开盘     收盘     最高     最低     成交量         成交额  \
# 0           0  2017-01-18  0.989  0.977  0.989  0.969  345605  33817947.0
# 1           1  2017-01-19  0.978  0.989  0.990  0.978  257716  25425534.0
# 2           2  2017-01-20  0.989  0.988  0.990  0.986   50980   5043289.0
# 3           3  2017-01-23  0.988  0.988  0.989  0.986   13739   1356129.0
# 4           4  2017-01-24  0.989  0.989  0.992  0.987   17937   1774398.0
#
#      振幅   涨跌幅    涨跌额   换手率
# 0  0.00  0.00  0.000  0.10
# 1  1.23  1.23  0.012  0.07
# 2  0.40 -0.10 -0.001  0.01
# 3  0.30  0.00  0.000  0.00
# 4  0.51  0.10  0.001  0.00

# %%
df.describe()
# Out:
#         Unnamed: 0           开盘           收盘           最高           最低  \
# count  1709.000000  1709.000000  1709.000000  1709.000000  1709.000000
# mean    854.000000     1.368280     1.367544     1.380144     1.356452
# std     493.490121     0.353967     0.353741     0.357149     0.349770
# min       0.000000     0.816000     0.816000     0.848000     0.812000
# 25%     427.000000     1.085000     1.086000     1.098000     1.075000
# 50%     854.000000     1.276000     1.277000     1.284000     1.268000
# 75%    1281.000000     1.518000     1.519000     1.527000     1.508000
# max    1708.000000     2.618000     2.570000     2.650000     2.552000
#
#                 成交量           成交额           振幅          涨跌幅          涨跌额  \
# count  1.709000e+03  1.709000e+03  1709.000000  1709.000000  1709.000000
# mean   5.330163e+06  6.264093e+08     1.735372     0.010053    -0.000056
# std    7.717787e+06  8.381122e+08     1.084354     1.795519     0.025471
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件并设置日期时间索引
df2 = pd.read_csv("/Users/bytedance/PycharmProjects/Finance_Project/used_etf/513050-中概互联网ETF.csv", parse_dates=['日期'])
df2.set_index('日期', inplace=True)

# 绘制曲线图
plt.figure(figsize=(100, 60))
plt.plot(df.index, df['收盘'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price')
plt.legend()
plt.show()
